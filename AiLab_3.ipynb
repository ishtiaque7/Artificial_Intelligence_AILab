# %% [markdown]
# <a href="https://colab.research.google.com/github/ishtiaque7/Artificial_Intelligence_AILab/blob/main/AiLab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv("/content/drive/MyDrive/Research/sample dataset/PriceDataSet.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df.head()
# Out:
#    weight  price
# 0       1     10
# 1       2     20
# 2       3     25
# 3       4     40
# 4       5     45

# %%
df.shape
# Out:
# (15, 2)

# %%
df.tail(8)
# Out:
#     weight  price
# 7        8    100
# 8        9    115
# 9       10    120
# 10      11    130
# 11      12    132
# 12      13    140
# 13      14    160
# 14      15    165

# %%
df.corr()
# Out:
#           weight     price
# weight  1.000000  0.989168
# price   0.989168  1.000000

# %%
import matplotlib.pyplot as plt
df.plot(kind = 'scatter', x = 'weight', y = 'price')

plt.show()

# %%
df.plot(kind='scatter',x='weight',y='price')
plt.xlabel("Weight of potato")
plt.ylabel("Price of potato")
plt.title("Prediction")
plt.show()

# %%
df["weight"].plot(kind='hist')
plt.show()
