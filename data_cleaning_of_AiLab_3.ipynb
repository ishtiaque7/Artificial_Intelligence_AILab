# %% [markdown]
# <a href="https://colab.research.google.com/github/ishtiaque7/Artificial_Intelligence_AILab/blob/main/data_cleaning_of_AiLab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/PriceDataSet-2.csv")

# %%
df.head()
# Out:
#    weight  price
# 0     1.0     10
# 1     2.0     20
# 2     3.0     25
# 3     4.0     40
# 4     5.0     45

# %%
df.shape
# Out:
# (17, 2)

# %%
df.tail(8)
# Out:
#     weight  price
# 9     10.0    120
# 10     NaN    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165
# 15    15.0    165
# 16     9.0    115

# %%
new_df=df.dropna()
print(df)
print(new_df)
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3      4.0     40
# 4      5.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10     NaN    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165
# 15    15.0    165
# 16     9.0    115
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3      4.0     40
# 4      5.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165
# 15    15.0    165
# 16     9.0    115

# %%
new_df=df.fillna(50)
print(new_df)
# Out:
#     weight  price
# 0      1.0     10
# 1      2.0     20
# 2      3.0     25
# 3      4.0     40
# 4      5.0     45
# 5      6.0     75
# 6      7.0     90
# 7      8.0    100
# 8      9.0    115
# 9     10.0    120
# 10    50.0    130
# 11    12.0    132
# 12    13.0    140
# 13    14.0    160
# 14    15.0    165

# %%
x = df["weight"].mean()
print("Mean is: ",x)
new_df=df.fillna(x)
print(new_df)
# Out:
# Mean is:  7.785714285714286
#        weight  price
# 0    1.000000     10
# 1    2.000000     20
# 2    3.000000     25
# 3    4.000000     40
# 4    5.000000     45
# 5    6.000000     75
# 6    7.000000     90
# 7    8.000000    100
# 8    9.000000    115
# 9   10.000000    120
# 10   7.785714    130
# 11  12.000000    132
# 12  13.000000    140
# 13  14.000000    160
# 14  15.000000    165

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15     True
# 16     True
# dtype: bool

# %%
df.describe()
# Out:
#           weight       price
# count  16.000000   17.000000
# mean    8.312500   96.882353
# std     4.614741   52.281548
# min     1.000000   10.000000
# 25%     4.750000   45.000000
# 50%     8.500000  115.000000
# 75%    12.250000  132.000000
# max    15.000000  165.000000
